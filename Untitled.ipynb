# %%
# %reload_ext autoreload
# %autoreload 2

from glob import glob
from tqdm import tqdm

import math
import numpy as np

import pandas as pd

import cv2
from skimage import morphology, registration
from skimage.restoration import inpaint

from scipy import ndimage, interpolate, signal, optimize

import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt

import pyvista as pv
pv.set_jupyter_backend("html")

import multiprocessing as mp
from joblib import Parallel, delayed

def mCPU(func, var, n_jobs=8,verbose=10):
    return Parallel(n_jobs=n_jobs, verbose=verbose)(delayed(func)(i) for i in var)

# %%
import io_utils

# %%
io_utils.
